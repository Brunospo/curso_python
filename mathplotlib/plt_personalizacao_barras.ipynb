# %% [markdown]
# # Mais personalizações possíveis

# %% [markdown]
# ## Gráfico de barras para apresentação
#
# Considere que você tem as quantidades de produtos vendidos em uma loja. Faça um gráfico de barras horizontais.

# %%
import matplotlib.pyplot as plt

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

# %%
plt.bar(produtos, quantidades)

plt.ylabel('Quantidade Vendida')
plt.xlabel('Produto')
plt.title('Quantidade de Produtos Vendidos')

plt.show()

# %%
from cycler import cycler

cmap = plt.get_cmap('Pastel2')
cores = [cmap(i) for i in range(cmap.N)]
cores_cycler = cycler('color', cores)
plt.rc('axes', prop_cycle=cores_cycler)

barras = plt.barh(produtos, quantidades)

for barra in barras:
  if barra.get_width() != max(quantidades):
    barra.set_color(cores[1])
    barra.set_alpha(0.5)

plt.bar_label(barras, labels=quantidades, padding=3, fontsize=10, fontweight='bold')

plt.title('Quantidade de Produtos Vendidos')

plt.box(False)
plt.xticks([])
plt.tick_params('y', length=0)

plt.show()

# %%
from cycler import cycler

cmap = plt.get_cmap('Pastel2')
cores = [cmap(i) for i in range(cmap.N)]
cores_cycler = cycler('color', cores)
plt.rc('axes', prop_cycle=cores_cycler)

barras = plt.barh(produtos, quantidades)

for barra in barras:
  if barra.get_width() != max(quantidades):
    barra.set_color(cores[1])
    barra.set_alpha(0.5)

plt.bar_label(barras, labels=[quantidade if quantidade == max(quantidades) else '' for quantidade in quantidades ], padding=3, fontsize=10, fontweight='bold')

plt.title('Quantidade de Produtos Vendidos')

plt.box(False)
plt.xticks([])
plt.tick_params('y', length=0)

plt.show()

# %%
from cycler import cycler

dados_ordenados = sorted(zip(quantidades, produtos))
quantidades_ordenadas = [dado[0] for dado in dados_ordenados]
produtos_ordenados = [dado[1] for dado in dados_ordenados]

cmap = plt.get_cmap('Pastel2')
cores = [cmap(i) for i in range(cmap.N)]
cores_cycler = cycler('color', cores)
plt.rc('axes', prop_cycle=cores_cycler)

barras = plt.barh(produtos_ordenados, quantidades_ordenadas)

for barra in barras:
  if barra.get_width() != max(quantidades):
    barra.set_color(cores[1])
    barra.set_alpha(0.5)

plt.bar_label(barras, labels=[quantidade if quantidade == max(quantidades) else '' for quantidade in quantidades_ordenadas ], padding=3, fontsize=10, fontweight='bold')

plt.title('Quantidade de Produtos Vendidos')

plt.box(False)
plt.xticks([])
plt.tick_params('y', length=0)

plt.show()

# %%
from cycler import cycler

dados_ordenados = sorted(zip(quantidades, produtos))
quantidades_ordenadas = [dado[0] for dado in dados_ordenados]
produtos_ordenados = [dado[1] for dado in dados_ordenados]

cmap = plt.get_cmap('Pastel2')
cores = [cmap(i) for i in range(cmap.N)]
cores_cycler = cycler('color', cores)
plt.rc('axes', prop_cycle=cores_cycler)

barras = plt.barh(produtos_ordenados, quantidades_ordenadas)

for barra in barras:
  if barra.get_width() != max(quantidades):
    barra.set_color(cores[1])
    barra.set_alpha(0.5)

plt.bar_label(barras, labels=[quantidade if quantidade == max(quantidades) else '' for quantidade in quantidades_ordenadas ], padding=3, fontsize=10, fontweight='bold')

plt.title('Quantidade de Produtos Vendidos')

plt.box(False)
plt.xticks([])
plt.tick_params('y', length=0)

plt.gca().invert_yaxis()

plt.show()

# %%
from cycler import cycler

dados_ordenados = sorted(zip(quantidades, produtos))
quantidades_ordenadas = [dado[0] for dado in dados_ordenados]
produtos_ordenados = [dado[1] for dado in dados_ordenados]

cmap = plt.get_cmap('Pastel2')
cores = [cmap(i) for i in range(cmap.N)]
cores_cycler = cycler('color', cores)
plt.rc('axes', prop_cycle=cores_cycler)

barras = plt.bar(produtos_ordenados, quantidades_ordenadas)

for barra in barras:
  if barra.get_height() != max(quantidades):
    barra.set_color(cores[1])
    barra.set_alpha(0.5)

plt.bar_label(barras, labels=[quantidade if quantidade == max(quantidades) else '' for quantidade in quantidades_ordenadas ], padding=3, fontsize=10, fontweight='bold')

plt.title('Quantidade de Produtos Vendidos')

plt.box(False)
plt.yticks([])
plt.tick_params('x', length=0)

plt.gca().invert_xaxis()

plt.show()
