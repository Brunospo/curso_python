# %% [markdown]
# ## Gráfico de barras empilhadas para apresentação

# %%
import matplotlib.pyplot as plt
from cycler import cycler

anos = [2018, 2019, 2020, 2021]
vendas_online = [5, 10, 15, 20]
vendas_loja = [10, 8, 6, 4]

# rc = runtime configuration (configuração quando executa)
cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)
 
plt.bar(anos, vendas_online, label='Online')
plt.bar(anos, vendas_loja, bottom=vendas_online, label='Loja')

# forçar os anos a serem exibidos como inteiros
plt.xticks(ticks=anos)

plt.xlabel('Ano')
plt.ylabel('Vendas (em milhões)')
plt.title('Vendas Online vs Loja')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from cycler import cycler

anos = [2018, 2019, 2020, 2021]
vendas_online = [5, 10, 15, 20]
vendas_loja = [10, 8, 6, 4]

# rc = runtime configuration (configuração quando executa)
cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)
 
loja_online = plt.bar(anos, vendas_online, label='Online')
loja_fisica = plt.bar(anos, vendas_loja, bottom=vendas_online, label='Loja')

plt.bar_label(loja_online, vendas_online, label_type='center')
plt.bar_label(loja_fisica, vendas_loja, label_type='center')

# forçar os anos a serem exibidos como inteiros
plt.xticks(ticks=anos)

plt.title('Vendas (em milhões) Online vs Loja')
plt.legend()

plt.tick_params('x', length = 0)
plt.yticks([])

plt.box(False)

plt.show()
